# %%
import pandas as pd

# %%
# recent 
df = pd.read_csv('covid19_vaccinations_in_the_united_states.csv')
df
# Out:
#     State/Territory/Federal Entity  Total Distributed  Total Administered  \
# 0                           Alaska             155700               88344
# 1                          Alabama             521225              221540
# 2                         Arkansas             368650              201676
# 3                   American Samoa              18450                6831
# 4                          Arizona             829500              360958
# 5                Bureau of Prisons              24750               23345
# 6                       California            4906525             2008220
# 7                         Colorado             692700              377283
# 8                      Connecticut             492850              306796
# 9             District of Columbia              91025               59793
# 10                 Dept of Defense             677025              311567
# 11                        Delaware             116325               60023
# ...

# %%
df[df['state']=='AK']
# Out:
#              date state dataQualityGrade  death  deathConfirmed  \
# 0      2021-01-23    AK                B  259.0             NaN
# 56     2021-01-22    AK                B  254.0             NaN
# 112    2021-01-21    AK                A  254.0             NaN
# 168    2021-01-20    AK                A  253.0             NaN
# 224    2021-01-19    AK               A+  230.0             NaN
# 280    2021-01-18    AK               A+  229.0             NaN
# 336    2021-01-17    AK               A+  229.0             NaN
# 392    2021-01-16    AK                A  229.0             NaN
# 448    2021-01-15    AK                A  229.0             NaN
# 504    2021-01-14    AK                A  228.0             NaN
# 560    2021-01-13    AK                A  226.0             NaN
# 616    2021-01-12    AK                A  224.0             NaN
# 672    2021-01-11    AK                A  224.0             NaN
# 728    2021-01-10    AK                A  224.0             NaN
# ...

# %%
d
